# %% [markdown]
# <a href="https://colab.research.google.com/github/Iannehuenlabat/Data/blob/main/Visualizaci%C3%B3n%2BLabat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = 'https://raw.githubusercontent.com/Iannehuenlabat/Data/main/spreadspoke_scores.csv'

# %%
NFL = pd.read_csv(data
                    )

# %%
mpl.style.use('bmh')

# %%
teamfavorite = pd.DataFrame()

# %%
teamfavorite = NFL['team_favorite_id'].value_counts()

# %%
team_favorite_id = pd.DataFrame(teamfavorite)

# %%
team_favorite_id.columns = ["total_fav"]

# %%
team_favorite_id.index.name = "id_team"

# %%
x= team_favorite_id.index
y= team_favorite_id['total_fav']

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.bar(team_favorite_id.index, height=y, width = 0.5)
ax.set_title('Historial de equipos favorito para llevarse la victoria')
ax.set_ylabel('Cantidad de veces que fue favorito')
ax.set_xlabel('Equipos')
# Out:
# Text(0.5, 0, 'Equipos')

# %%
prom_temperatura = pd.DataFrame()
prom_temperatura = NFL[['schedule_season', 'weather_temperature']].copy()

# %%
prom_temperatura.index = prom_temperatura ['schedule_season']
prom_temperatura = prom_temperatura.drop('schedule_season', axis= 'columns')

# %%
prom_temperatura
# Out:
#                  weather_temperature
# schedule_season
# 1966                            83.0
# 1966                            81.0
# 1966                            70.0
# 1966                            82.0
# 1966                            64.0
# ...                              ...
# 2023                            72.0
# 2023                             NaN
# 2023                             NaN
# 2023                             NaN
# 2023                             NaN
#
# [13788 rows x 1 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# prom_temperatura['weather_temperature'].plot(kind='hist', bins=20, title='weather_temperature')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# ...

# %%
prom_temperatura = prom_temperatura.dropna(axis=1)
prom_temperatura.info
# Out:
# <bound method DataFrame.info of Empty DataFrame
# Columns: []
# Index: [1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, 1966, ...]
#
# [13788 rows x 0 columns]>

# %%
ax.boxplot?

# %%
fig, ax = plt.subplots(figsize=(15,5))
ax.boxplot(x=prom_temperatura.T,)
ax.set_title('Promedio de temperatura por temporada')
ax.set_xlabel('Temporada')
ax.set_ylabel('Temperatura')
# Out:
# Text(0, 0.5, 'Temperatura')

# %%
Localia = NFL['stadium_neutral'].value_counts()
Localia = pd.DataFrame(Localia)
Localia
# Out:
#        stadium_neutral
# False            13673
# True               115

# %%
fig,ax = plt.subplots(figsize =(10, 6))
ax.pie(Localia, labels=Localia['stadium_neutral'] ,autopct='%1.1f%%')
ax.set_title('Cantidad de partidos con equipo local')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-a0405ccc36d7> in <cell line: 2>()
#       1 fig,ax = plt.subplots(figsize =(10, 6))
# ----> 2 ax.pie(Localia, labels=Localia['stadium_neutral'] ,autopct='%1.1f%%')
#       3 ax.set_title('Cantidad de partidos con equipo local')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
